# %% [markdown]
# Nombre: Cristina Molina
#
# # Bibliotecas

# %%
import os  # Interacción con el sistema de archivos.
import re  # Operaciones de expresiones regulares.
import csv  # Lectura y escritura de archivos CSV.
import pandas as pd  # Manipulación y análisis de datos tabulares.
from sklearn.metrics.pairwise import cosine_similarity  # Cálculo de similitud coseno.

# %% [markdown]
# # Prepocesamiento de la Data

# %% [markdown]
# 1. **Función de preprocesamiento de texto (`preprocess_text`):**
#    - **Descripción:** Esta función lee un archivo de texto, lo convierte a minúsculas, divide el texto en tokens (palabras) y elimina duplicados.
#    - **Argumentos:**
#      - `file_path` (str): Ruta del archivo de texto a procesar.
#    - **Retorno:** Retorna una lista de tokens procesados.
#
# 2. **Procesamiento de archivos de texto:**
#    - **Descripción:** Este bloque de código procesa cada archivo de texto en un directorio especificado, utilizando la función de preprocesamiento `preprocess_text`.
#    - **Directorio:** El directorio de los archivos de texto se especifica en la variable `directory`.
#    - **Salida:** Se almacenan los tokens procesados de todos los archivos en la lista `all_tokens`.
#
# 3. **Guardado de tokens en un archivo CSV:**
#    - **Descripción:** Los tokens únicos se guardan en un archivo CSV.
#    - **Archivo de salida:** El nombre del archivo CSV se especifica en la variable `csv_file`.
#    - **Contenido del CSV:** Contiene una sola columna llamada "Token".
#
# 4. **Lectura y visualización del archivo CSV:**
#    - **Descripción:** Lee el archivo CSV generado y muestra su contenido.
#    - **Impresión:** Se imprime el contenido del archivo CSV en la consola.

# %%
# Función de prepocesamiento
def preprocess_text(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Convertir el texto a minúsculas
    text = text.lower()

    # Dividir el texto en tokens (palabras)
    tokens = re.findall(r'\b(?![0-9]+\b)\w+\b', text)

    # Eliminar duplicados de la lista de tokens
    tokens = list(dict.fromkeys(tokens))

    return tokens

# Directorio donde se encuentran los archivos TXT
directory = '/content/drive/MyDrive/DATA'

# Lista para almacenar los tokens procesados de todos los archivos
all_tokens = []

# Procesar cada archivo en el directorio
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory, filename)
        tokens = preprocess_text(file_path)
        all_tokens.extend(tokens)

# Eliminar duplicados de la lista de tokens de todos los archivos
all_tokens = list(dict.fromkeys(all_tokens))

# %%
# Guardar la lista de tokens en un archivo CSV
csv_file = 'tokens.csv'
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Token"])  # Escribir encabezado
    writer.writerows([[token] for token in all_tokens])

print(f"Se han guardado los tokens en {csv_file}.")
# Out:
# Se han guardado los tokens en tokens.csv.

# %%
# Leer y mostrar el contenido del archivo CSV
print("Contenido del archivo CSV:")
with open(csv_file, 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# Contenido del archivo CSV:
# ['Token']
# ['westfalenpark']
# ['es']
# ['uno']
# ['de']
# ['los']
# ['parques']
# ['urbanos']
# ['más']
# ['grandes']
# ['europa']
# ['rosarium']
# ['que']
# ['alberga']
# ['una']
# ['las']
# ['colecciones']
# ['extensas']
# ['rosas']
# ['en']
# ['el']
# ['mundo']
# ['y']
# ['la']
# ['un']
# ['lugar']
# ['destacado']
# ['para']
# ['visitantes']
# ['dortmund']
# ['parque']
# ['famoso']
# ['por']
# ['su']
# ['torre']
# ['florian']
# ['ofrece']
# ['vistas']
# ['panorámicas']
# ['ciudad']
# ['u']
# ['tower']
# ['centro']
# ['arte']
# ['creatividad']
# ['antigua']
# ['cervecería']
# ['reconvertida']
# ['ahora']
# ['dinámico']
# ['museo']
# ['ostwall']
# ['espacios']
# ['exposiciones']
# ['estudios']
# ['artistas']
# ['símbolo']
# ['transformación']
# ['cultural']
# ['tiene']
# ['larga']
# ['tradición']
# ['cervecera']
# ['visita']
# ['a']
# ['sus']
# ['muchas']
# ['cervecerías']
# ['parada']
# ['obligatoria']
# ['ofrecen']
# ['tours']
# ['incluyen']
# ['degustaciones']
# ['cervezas']
# ['locales']
# ['como']
# ['dortmunder']
# ['export']
# ['lager']
# ['orgullo']
# ['mercado']
# ['navidad']
# ['posiblemente']
# ['alto']
# ['mercados']
# ['navideños']
# ['del']
# ['país']
# ['puestos']
# ['venden']
# ['artesanías']
# ['alimentos']
# ['bebidas']
# ['tradicionales']
# ['evento']
# ['imperdible']
# ['durante']
# ['temporada']
# ['festiva']
# ['fútbol']
# ['alemán']
# ['inaugurado']
# ['experiencia']
# ['interactiva']
# ['celebra']
# ['rica']
# ['historia']
# ['ubicado']
# ['atrae']
# ['aficionados']
# ['todo']
# ['destaca']
# ['cuentan']
# ['desde']
# ['primeros']
# ['días']
# ['deporte']
# ['hasta']
# ['triunfos']
# ['copas']
# ['situada']
# ['región']
# ['ruhr']
# ['alemania']
# ['se']
# ['remonta']
# ['al']
# ['año']
# ['originalmente']
# ['pequeña']
# ['villa']
# ['creció']
# ['convertirse']
# ['importante']
# ['industrial']
# ['especialmente']
# ['conocida']
# ['producción']
# ['acero']
# ['cerveza']
# ['borussia']
# ['signal']
# ['iduna']
# ['park']
# ['clubes']
# ['populares']
# ['exitosos']
# ['equipo']
# ['juega']
# ['partidos']
# ['casa']
# ['conocido']
# ['increíble']
# ['atmósfera']
# ['muro']
# ['amarillo']
# ['tribuna']
# ['sur']
# ['apasionados']
# ['zoológico']
# ['excelente']
# ['familias']
# ['amantes']
# ['naturaleza']
# ['con']
# ['animales']
# ['enfoque']
# ['especial']
# ['conservación']
# ['especies']
# ['amenazadas']
# ['proporciona']
# ['educativa']
# ['entretenida']
# ['real']
# ['madrid']
# ['estadio']
# ['santiago']
# ['bernabéu']
# ['famosos']
# ['este']
# ['meca']
# ['permiten']
# ['explorar']
# ['gran']
# ['vía']
# ['calles']
# ['famosas']
# ['tiendas']
# ['teatros']
# ['arquitectura']
# ['emblemática']
# ['bullicioso']
# ['bulevar']
# ['punto']
# ['encuentro']
# ['turistas']
# ['igual']
# ['retiro']
# ['pulmón']
# ['verde']
# ['antiguamente']
# ['perteneciente']
# ['monarquía']
# ['española']
# ['hectáreas']
# ['respiro']
# ['vida']
# ['urbana']
# ['estanques']
# ['jardines']
# ['palacio']
# ['cristal']
# ['capital']
# ['españa']
# ['siglo']
# ['ix']
# ['fue']
# ['fundada']
# ['musulmanes']
# ['nombre']
# ['proviene']
# ['árabe']
# ['majrit']
# ['significa']
# ['fuente']
# ['agua']
# ['lo']
# ['largo']
# ['siglos']
# ['ha']
# ['convertido']
# ['político']
# ['económico']
# ['gastronomía']
# ['madrileña']
# ['famosa']
# ['vibrante']
# ['escena']
# ['gastronómica']
# ['incluye']
# ['tapas']
# ['pequeños']
# ['bares']
# ['restaurantes']
# ['alta']
# ['cocina']
# ['platos']
# ['típicos']
# ['cocido']
# ['madrileño']
# ['patatas']
# ['bravas']
# ['son']
# ['esenciales']
# ['cualquier']
# ['visitante']
# ['prado']
# ['museos']
# ['destino']
# ['imprescindible']
# ['visitan']
# ['impresionante']
# ['colección']
# ['obras']
# ['velázquez']
# ['goya']
# ['greco']
# ['otros']
# ['maestros']
# ['europeos']
# ['residencias']
# ['oficiales']
# ['familia']
# ['aunque']
# ['usa']
# ['principalmente']
# ['ceremonias']
# ['estado']
# ['habitaciones']
# ['grande']
# ['occidental']
# ['testimonio']
# ['esplendor']
# ['segunda']
# ['guerra']
# ['mundial']
# ['objetivo']
# ['significativo']
# ['bombardeos']
# ['debido']
# ['industria']
# ['pesada']
# ['hoy']
# ['día']
# ['varios']
# ['monumentos']
# ['reflexiones']
# ['sobre']
# ['período']
# ['efectos']
# ['reinoldikirche']
# ['iglesia']
# ['san']
# ['reinold']
# ['edificio']
# ['antiguo']
# ['datando']
# ['xiii']
# ['referencia']
# ['histórico']
# ['mirada']
# ['pasado']
# ['medieval']
# ['río']
# ['lineal']
# ['manzanares']
# ['ejemplo']
# ['perfecto']
# ['cómo']
# ['transformado']
# ['áreas']
# ['industriales']
# ['verdes']
# ['vibrantes']
# ['popular']
# ['caminar']
# ['andar']
# ['bicicleta']
# ['disfrutar']
# ['actividades']
# ['aire']
# ['libre']
# ['nochevieja']
# ['puerta']
# ['sol']
# ['corazón']
# ['donde']
# ['miles']
# ['reúnen']
# ['cada']
# ['dar']
# ['bienvenida']
# ['nuevo']
# ['comer']
# ['doce']
# ['uvas']
# ['suerte']
# ['campanadas']
# ['reloj']
# ['todos']
# ['deberían']
# ['experimentar']
# ['navideña']
# ['transforma']
# ['festivos']
# ['luces']
# ['deslumbrantes']
# ['decoraciones']
# ['plaza']
# ['mayor']
# ['convierte']
# ['enorme']
# ['pueden']
# ['encontrar']
# ['tipo']
# ['regalos']
# ['delicias']

# %% [markdown]
# # Matriz de Conteo de Palabras

# %% [markdown]
# 1. **Procesamiento de archivos de texto y conteo de palabras:**
#    - **Descripción:** Este bloque de código recorre cada archivo de texto en un directorio especificado, realiza el preprocesamiento del texto y cuenta la frecuencia de cada palabra en cada archivo.
#    - **Tokenización y conteo:** Para cada archivo, se tokeniza el texto y se cuentan las ocurrencias de cada token en el texto.
#    - **Almacenamiento de resultados:** Los conteos de palabras se almacenan en un DataFrame de Pandas llamado `dfConteos`.
#    - **Columnas:** Cada columna del DataFrame representa una palabra única encontrada en los textos.
#    - **Filas:** Cada fila del DataFrame representa un archivo de texto, con los conteos de palabras correspondientes.

# %%
# Lista para almacenar los tokens procesados de todos los archivos
all_tokens = []

# Procesar cada archivo en el directorio
for filename in os.listdir("/content/drive/MyDrive/DATA"):
    if filename.endswith('.txt'):
        file_path = os.path.join("/content/drive/MyDrive/DATA", filename)
        tokens = preprocess_text(file_path)
        all_tokens.extend(tokens)

# Eliminar duplicados de la lista de tokens de todos los archivos
all_tokens = list(dict.fromkeys(all_tokens))

# Definir los nombres de los textos y los conteos de palabras relacionadas con cada categoría
textos = os.listdir("/content/drive/MyDrive/DATA")

# Crear una lista de listas para almacenar los conteos de palabras
conteos = []

# Procesar cada archivo en el directorio
for filename in os.listdir("/content/drive/MyDrive/DATA"):
    if filename.endswith('.txt'):
        file_path = os.path.join("/content/drive/MyDrive/DATA", filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read().lower()
            # Inicializar la lista de conteos para este archivo
            conteo = []
            # Contar cuántas veces aparece cada palabra de la lista en el texto
            for token in all_tokens:
                count = text.count(token)
                conteo.append(count)
            # Agregar los conteos de palabras para este archivo a la lista de conteos
            conteos.append(conteo)

# Crear un DataFrame de Pandas con los conteos de palabras
dfConteos = pd.DataFrame(conteos, columns=all_tokens, index=textos)

# Mostrar el DataFrame
dfConteos
# Out:
#                                                     westfalenpark  es  uno  \
# 12. Westfalenpark.txt                                           2   9    1
# 15. U-Tower - Centro de Arte y Creatividad.txt                  0   5    0
# 17. La cervecería Dortmund.txt                                 0   4    0
# 14. Mercado de Navidad de Dortmund.txt                          0   7    1
# 13. Museo del Fútbol Alemán.txt                               0   3    0
# 11. Historia de Dortmund.txt                                    0   1    0
# 16. Borussia Dortmund y el Signal Iduna Park.txt                0   3    1
# 20. Zoológico de Dortmund.txt                                  0   6    0
# 07. Real Madrid y el Estadio Santiago Bernabéu...              0   7    1
# 06. Gran Vía.txt                                               0   5    0
# 04. Parque del Retiro.txt                                       0   7    0
# 01. Historia de Madrid.txt                                      0   3    0
# 05. Gastronomía Madrileña.txt                                 0   8    0
# 03. Museo del Prado.txt                                         0   6    1
# 02. El Palacio Real.txt                                         0  10    0
# 19. Dortmund durante la Segunda Guerra Mundial.txt              0   3    0
# 18. La Reinoldikirche.txt                                       0   4    0
# 10. Madrid Río.txt                                             0   8    0
# 09. Nochevieja en Puerta del Sol.txt                            0   3    0
# 08 Navidad en Madrid.txt                                        0   6    0
#
#                                                     de  los  parques  urbanos  \
# 12. Westfalenpark.txt                                7    2        1        1
# 15. U-Tower - Centro de Arte y Creatividad.txt       6    0        0        0
# 17. La cervecería Dortmund.txt                      5    0        0        0
# 14. Mercado de Navidad de Dortmund.txt              11    1        0        0
# 13. Museo del Fútbol Alemán.txt                   10    2        0        0
# 11. Historia de Dortmund.txt                         3    0        0        0
# 16. Borussia Dortmund y el Signal Iduna Park.txt     3    1        0        0
# 20. Zoológico de Dortmund.txt                       5    0        0        0
# 07. Real Madrid y el Estadio Santiago Bernabéu...   3    3        0        0
# 06. Gran Vía.txt                                    3    0        0        0
# 04. Parque del Retiro.txt                            7    0        0        0
# 01. Historia de Madrid.txt                           6    3        0        0
# 05. Gastronomía Madrileña.txt                      3    0        0        0
# 03. Museo del Prado.txt                              8    2        0        0
# 02. El Palacio Real.txt                             11    0        0        0
# 19. Dortmund durante la Segunda Guerra Mundial.txt   3    1        0        0
# 18. La Reinoldikirche.txt                            5    1        0        0
# 10. Madrid Río.txt                                  5    0        0        0
# 09. Nochevieja en Puerta del Sol.txt                 8    0        0        0
# 08 Navidad en Madrid.txt                             8    1        0        0
#
#                                                     más  grandes  europa  ...  \
# 12. Westfalenpark.txt                                 2        1       1  ...
# 15. U-Tower - Centro de Arte y Creatividad.txt        0        0       0  ...
# 17. La cervecería Dortmund.txt                       0        0       0  ...
# 14. Mercado de Navidad de Dortmund.txt                2        1       0  ...
# 13. Museo del Fútbol Alemán.txt                     0        0       0  ...
# 11. Historia de Dortmund.txt                          0        0       0  ...
# 16. Borussia Dortmund y el Signal Iduna Park.txt      1        0       0  ...
# 20. Zoológico de Dortmund.txt                        1        0       0  ...
# 07. Real Madrid y el Estadio Santiago Bernabéu...    1        0       0  ...
# 06. Gran Vía.txt                                     1        0       0  ...
# 04. Parque del Retiro.txt                             0        0       0  ...
# 01. Historia de Madrid.txt                            0        0       0  ...
# 05. Gastronomía Madrileña.txt                       0        0       0  ...
# 03. Museo del Prado.txt                               1        0       0  ...
# 02. El Palacio Real.txt                               2        0       1  ...
# 19. Dortmund durante la Segunda Guerra Mundial.txt    0        0       0  ...
# 18. La Reinoldikirche.txt                             1        0       0  ...
# 10. Madrid Río.txt                                   0        0       0  ...
# 09. Nochevieja en Puerta del Sol.txt                  0        0       0  ...
# 08 Navidad en Madrid.txt                              0        0       0  ...
#
#                                                     decoraciones  plaza  \
# 12. Westfalenpark.txt                                          0      0
# 15. U-Tower - Centro de Arte y Creatividad.txt                 0      0
# 17. La cervecería Dortmund.txt                                0      0
# 14. Mercado de Navidad de Dortmund.txt                         0      0
# 13. Museo del Fútbol Alemán.txt                              0      0
# 11. Historia de Dortmund.txt                                   0      0
# 16. Borussia Dortmund y el Signal Iduna Park.txt               0      0
# 20. Zoológico de Dortmund.txt                                 0      0
# 07. Real Madrid y el Estadio Santiago Bernabéu...             0      0
# 06. Gran Vía.txt                                              0      0
# 04. Parque del Retiro.txt                                      0      0
# 01. Historia de Madrid.txt                                     0      0
# 05. Gastronomía Madrileña.txt                                0      0
# 03. Museo del Prado.txt                                        0      0
# 02. El Palacio Real.txt                                        0      0
# 19. Dortmund durante la Segunda Guerra Mundial.txt             0      0
# 18. La Reinoldikirche.txt                                      0      0
# 10. Madrid Río.txt                                            0      0
# 09. Nochevieja en Puerta del Sol.txt                           0      0
# 08 Navidad en Madrid.txt                                       1      1
#
#                                                     mayor  convierte  enorme  \
# 12. Westfalenpark.txt                                   0          0       0
# 15. U-Tower - Centro de Arte y Creatividad.txt          0          0       0
# 17. La cervecería Dortmund.txt                         0          0       0
# 14. Mercado de Navidad de Dortmund.txt                  0          0       0
# 13. Museo del Fútbol Alemán.txt                       0          0       0
# 11. Historia de Dortmund.txt                            0          0       0
# 16. Borussia Dortmund y el Signal Iduna Park.txt        0          0       0
# 20. Zoológico de Dortmund.txt                          0          0       0
# 07. Real Madrid y el Estadio Santiago Bernabéu...      0          0       0
# 06. Gran Vía.txt                                       0          0       0
# 04. Parque del Retiro.txt                               0          0       0
# 01. Historia de Madrid.txt                              0          0       0
# 05. Gastronomía Madrileña.txt                         0          0       0
# 03. Museo del Prado.txt                                 0          0       0
# 02. El Palacio Real.txt                                 0          0       0
# 19. Dortmund durante la Segunda Guerra Mundial.txt      0          0       0
# 18. La Reinoldikirche.txt                               0          0       0
# 10. Madrid Río.txt                                     0          0       0
# 09. Nochevieja en Puerta del Sol.txt                    0          0       0
# 08 Navidad en Madrid.txt                                1          1       1
#
#                                                     pueden  encontrar  tipo  \
# 12. Westfalenpark.txt                                    0          0     0
# 15. U-Tower - Centro de Arte y Creatividad.txt           0          0     0
# 17. La cervecería Dortmund.txt                          0          0     0
# 14. Mercado de Navidad de Dortmund.txt                   0          0     0
# 13. Museo del Fútbol Alemán.txt                        0          0     0
# 11. Historia de Dortmund.txt                             0          0     0
# 16. Borussia Dortmund y el Signal Iduna Park.txt         0          0     0
# 20. Zoológico de Dortmund.txt                           0          0     0
# 07. Real Madrid y el Estadio Santiago Bernabéu...       0          0     0
# 06. Gran Vía.txt                                        0          0     0
# 04. Parque del Retiro.txt                                0          0     0
# 01. Historia de Madrid.txt                               0          0     0
# 05. Gastronomía Madrileña.txt                          0          0     0
# 03. Museo del Prado.txt                                  0          0     0
# 02. El Palacio Real.txt                                  0          0     0
# 19. Dortmund durante la Segunda Guerra Mundial.txt       0          0     0
# 18. La Reinoldikirche.txt                                0          0     0
# 10. Madrid Río.txt                                      0          0     0
# 09. Nochevieja en Puerta del Sol.txt                     0          0     0
# 08 Navidad en Madrid.txt                                 1          1     1
#
#                                                     regalos  delicias
# 12. Westfalenpark.txt                                     0         0
# 15. U-Tower - Centro de Arte y Creatividad.txt            0         0
# 17. La cervecería Dortmund.txt                           0         0
# 14. Mercado de Navidad de Dortmund.txt                    0         0
# 13. Museo del Fútbol Alemán.txt                         0         0
# 11. Historia de Dortmund.txt                              0         0
# 16. Borussia Dortmund y el Signal Iduna Park.txt          0         0
# 20. Zoológico de Dortmund.txt                            0         0
# 07. Real Madrid y el Estadio Santiago Bernabéu...        0         0
# 06. Gran Vía.txt                                         0         0
# 04. Parque del Retiro.txt                                 0         0
# 01. Historia de Madrid.txt                                0         0
# 05. Gastronomía Madrileña.txt                           0         0
# 03. Museo del Prado.txt                                   0         0
# 02. El Palacio Real.txt                                   0         0
# 19. Dortmund durante la Segunda Guerra Mundial.txt        0         0
# 18. La Reinoldikirche.txt                                 0         0
# 10. Madrid Río.txt                                       0         0
# 09. Nochevieja en Puerta del Sol.txt                      0         0
# 08 Navidad en Madrid.txt                                  1         1
#
# [20 rows x 368 columns]

# %%
# Guardar el contenido del DataFrame en un archivo CSV
csv_matrizConteo = 'matrizConteo.csv'
dfConteos.to_csv(csv_matrizConteo)

print(f"Se ha guardado el contenido del DataFrame en {csv_matrizConteo}.")
# Out:
# Se ha guardado el contenido del DataFrame en matrizConteo.csv.

# %% [markdown]
# # Matriz de querys y términos

# %% [markdown]
# 1. **Procesamiento de las querys y conteo de palabras:**
#    - **Descripción:** Este bloque de código realiza un proceso similar al anterior, pero en lugar de procesar archivos de texto ordinarios, procesa archivos de consulta almacenados en un directorio específico.
#    - **Tokenización y conteo:** Para cada archivo de consulta, se tokeniza el texto y se cuentan las ocurrencias de cada token en el texto.
#    - **Almacenamiento de resultados:** Los conteos de palabras de las consultas se almacenan en un DataFrame de Pandas llamado `dfConteosQ`.
#    - **Columnas:** Cada columna del DataFrame representa una palabra única encontrada en los textos de consulta.
#    - **Filas:** Cada fila del DataFrame representa un archivo de consulta, con los conteos de palabras correspondientes.

# %%
# Ruta base para construir los tokens
base_path = "/content/drive/MyDrive/DATA"

# Lista para almacenar los tokens procesados de todos los archivos en la ruta base
all_tokens = []

# Procesar cada archivo en la ruta base
for filename in os.listdir(base_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(base_path, filename)
        tokens = preprocess_text(file_path)  # Suponiendo que tienes la función preprocess_text definida
        all_tokens.extend(tokens)

# Eliminar duplicados de la lista de tokens de todos los archivos
all_tokens = list(dict.fromkeys(all_tokens))

# Definir los nombres de los textos y los conteos de palabras relacionadas con cada categoría
textosQ = os.listdir("/content/drive/MyDrive/querys")

# Crear una lista de listas para almacenar los conteos de palabras
conteosQ = []

# Procesar cada archivo en el directorio
for filename in os.listdir("/content/drive/MyDrive/querys"):
    if filename.endswith('.txt'):
        file_path = os.path.join("/content/drive/MyDrive/querys", filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            textQ = file.read().lower()  # Cambio aquí, utilizar textQ en lugar de textosQ
            # Inicializar la lista de conteos para este archivo
            conteoQ = []
            # Contar cuántas veces aparece cada palabra de la lista en el texto
            for token in all_tokens:
                count = textQ.count(token)
                conteoQ.append(count)
            # Agregar los conteos de palabras para este archivo a la lista de conteos
            conteosQ.append(conteoQ)

# Crear un DataFrame de Pandas con los conteos de palabras
dfConteosQ = pd.DataFrame(conteosQ, columns=all_tokens, index=textosQ)

# Mostrar el DataFrame
dfConteosQ
# Out:
#              westfalenpark  es  uno  de  los  parques  urbanos  más  grandes  \
# query1.txt               0   1    0   2    0        0        0    0        0
# query2.txt               0   2    0   1    0        0        0    0        0
# query3.txt               0   0    0   1    0        0        0    0        0
# query4.txt               0   2    0   2    1        1        1    0        0
# query5.txt               0   1    0   0    0        0        0    0        0
# query6.txt               0   0    0   1    0        0        0    0        0
# query7.txt               0   2    0   2    0        0        0    0        0
# query8.txt               0   1    0   1    0        0        0    0        0
# query9.txt               0   1    0   2    0        0        0    0        0
# query10.txt              0   1    0   1    0        0        0    0        0
# query11.txt              0   2    0   1    0        0        0    0        0
# query12.txt              0   1    0   1    0        0        0    0        0
# query13.txt              0   1    0   1    0        0        0    0        0
# query14.txt              0   0    0   0    0        0        0    0        0
# query15.txt              0   1    0   3    0        0        0    0        0
# query16.txt              0   2    0   3    0        0        0    0        0
# query17.txt              0   1    0   1    0        0        0    0        0
# query18.txt              0   4    0   2    0        0        0    0        0
# query19.txt              0   2    0   2    0        0        0    0        0
# query20.txt              0   0    0   1    0        0        0    0        0
#
#              europa  ...  decoraciones  plaza  mayor  convierte  enorme  \
# query1.txt        0  ...             0      0      0          0       0
# query2.txt        1  ...             0      0      0          0       0
# query3.txt        0  ...             0      0      0          0       0
# query4.txt        0  ...             0      0      0          0       0
# query5.txt        0  ...             0      0      0          0       0
# query6.txt        1  ...             0      0      0          0       0
# query7.txt        0  ...             0      0      0          0       0
# query8.txt        1  ...             0      0      0          0       0
# query9.txt        0  ...             0      0      0          0       0
# query10.txt       0  ...             0      0      0          0       0
# query11.txt       1  ...             0      0      0          0       0
# query12.txt       0  ...             0      0      0          0       0
# query13.txt       0  ...             0      0      0          0       0
# query14.txt       1  ...             0      0      0          0       0
# query15.txt       0  ...             0      0      0          0       0
# query16.txt       0  ...             0      0      0          0       0
# query17.txt       0  ...             0      0      0          0       0
# query18.txt       0  ...             0      0      0          0       0
# query19.txt       0  ...             0      0      0          0       0
# query20.txt       0  ...             0      0      0          0       0
#
#              pueden  encontrar  tipo  regalos  delicias
# query1.txt        0          0     0        0         0
# query2.txt        0          0     0        0         0
# query3.txt        0          0     0        0         0
# query4.txt        0          0     0        0         0
# query5.txt        0          0     0        0         0
# query6.txt        0          0     0        0         0
# query7.txt        0          0     0        0         0
# query8.txt        0          0     0        0         0
# query9.txt        0          0     0        0         0
# query10.txt       0          0     0        0         0
# query11.txt       0          0     0        0         0
# query12.txt       0          0     0        0         0
# query13.txt       0          0     0        0         0
# query14.txt       0          0     0        0         0
# query15.txt       0          0     0        0         0
# query16.txt       0          0     0        0         0
# query17.txt       0          0     0        0         0
# query18.txt       0          0     0        0         0
# query19.txt       0          0     0        0         0
# query20.txt       0          0     0        0         0
#
# [20 rows x 368 columns]

# %%
# Guardar el contenido del DataFrame en un archivo CSV
csv_matrizQuery = 'matrizQuery.csv'
dfConteosQ.to_csv(csv_matrizQuery)

print(f"Se ha guardado el contenido del DataFrame en {csv_matrizQuery}.")
# Out:
# Se ha guardado el contenido del DataFrame en matrizQuery.csv.

# %% [markdown]
# # Similitud Coseno por cada query

# %% [markdown]
# 1. **Cálculo de similitud de coseno entre consultas y documentos:**
#    - **Descripción:** Este bloque de código calcula la similitud coseno entre cada consulta y cada documento basándose en los vectores de frecuencia de palabras obtenidos previamente para ambos conjuntos de datos.
#    - **Vectores de documentos:** Se extraen los vectores de frecuencia de palabras de los documentos del DataFrame `dfConteos`.
#    - **Vectores de consultas:** Se extraen los vectores de frecuencia de palabras de las consultas del DataFrame `dfConteosQ`.
#    - **Cálculo de similitud:** Utilizando la función `cosine_similarity` de scikit-learn, se calcula la similitud coseno entre los vectores de consulta y los vectores de documentos.
#    - **Almacenamiento de resultados:** Las similitudes calculadas se almacenan en un DataFrame de Pandas llamado `df_similitudes`.
#    - **Índices y columnas:** Los índices del DataFrame representan los nombres de las consultas, mientras que las columnas representan los nombres de los documentos. Los valores en cada celda del DataFrame son las similitudes coseno entre la consulta correspondiente y el documento respectivo.

# %%
# Iterar sobre cada fila del DataFrame y convertirla en un vector
vectores_documentos = dfConteos.values

# Iterar sobre cada fila del DataFrame de consultas y convertirla en un vector
vectores_consultas = dfConteosQ.values

# Calcular la similitud coseno entre cada consulta y cada documento
similitudes = cosine_similarity(vectores_consultas, vectores_documentos)

# Convertir las similitudes en un DataFrame para una mejor visualización
df_similitudes = pd.DataFrame(similitudes, index=dfConteosQ.index, columns=dfConteos.index)

# %%
df_similitudes
# Out:
#              12. Westfalenpark.txt  \
# query1.txt                0.888786
# query2.txt                0.801201
# query3.txt                0.904543
# query4.txt                0.935752
# query5.txt                0.871477
# query6.txt                0.539168
# query7.txt                0.893785
# query8.txt                0.794359
# query9.txt                0.899192
# query10.txt               0.901537
# query11.txt               0.788382
# query12.txt               0.865754
# query13.txt               0.898641
# query14.txt               0.793947
# query15.txt               0.817013
# query16.txt               0.787307
# query17.txt               0.884056
# query18.txt               0.862584
# query19.txt               0.929179
# query20.txt               0.853205
#
#              15. U-Tower - Centro de Arte y Creatividad.txt  \
# query1.txt                                         0.882145
# query2.txt                                         0.762217
# query3.txt                                         0.891105
# query4.txt                                         0.869539
# query5.txt                                         0.866334
# query6.txt                                         0.491321
# query7.txt                                         0.888510
# query8.txt                                         0.795193
# query9.txt                                         0.893885
# query10.txt                                        0.885916
# query11.txt                                        0.762215
# query12.txt                                        0.889597
# query13.txt                                        0.879488
# query14.txt                                        0.807282
# query15.txt                                        0.859049
# query16.txt                                        0.772318
# query17.txt                                        0.899879
# query18.txt                                        0.839295
# query19.txt                                        0.925762
# query20.txt                                        0.850469
#
#              17. La cervecería Dortmund.txt  \
# query1.txt                          0.862907
# query2.txt                          0.718931
# query3.txt                          0.915195
# query4.txt                          0.876109
# query5.txt                          0.825012
# query6.txt                          0.499347
# query7.txt                          0.828037
# query8.txt                          0.756720
# query9.txt                          0.916350
# query10.txt                         0.893040
# query11.txt                         0.747485
# query12.txt                         0.821816
# query13.txt                         0.874716
# query14.txt                         0.763407
# query15.txt                         0.755650
# query16.txt                         0.703293
# query17.txt                         0.865982
# query18.txt                         0.786121
# query19.txt                         0.894902
# query20.txt                         0.847558
#
#              14. Mercado de Navidad de Dortmund.txt  \
# query1.txt                                 0.871421
# query2.txt                                 0.767364
# query3.txt                                 0.839025
# query4.txt                                 0.871780
# query5.txt                                 0.839921
# query6.txt                                 0.570189
# query7.txt                                 0.918295
# query8.txt                                 0.766131
# query9.txt                                 0.838250
# query10.txt                                0.823763
# query11.txt                                0.722514
# query12.txt                                0.862156
# query13.txt                                0.860689
# query14.txt                                0.784722
# query15.txt                                0.887846
# query16.txt                                0.854820
# query17.txt                                0.860753
# query18.txt                                0.854002
# query19.txt                                0.903873
# query20.txt                                0.837103
#
#              13. Museo del Fútbol Alemán.txt  11. Historia de Dortmund.txt  \
# query1.txt                            0.837419                      0.854727
# query2.txt                            0.724263                      0.719227
# query3.txt                            0.862818                      0.928355
# query4.txt                            0.848676                      0.845617
# query5.txt                            0.791155                      0.867493
# query6.txt                            0.561249                      0.556794
# query7.txt                            0.863528                      0.819661
# query8.txt                            0.787147                      0.779365
# query9.txt                            0.874803                      0.907082
# query10.txt                           0.858840                      0.887640
# query11.txt                           0.735612                      0.715178
# query12.txt                           0.797925                      0.833473
# query13.txt                           0.839792                      0.866301
# query14.txt                           0.736070                      0.819704
# query15.txt                           0.785051                      0.765156
# query16.txt                           0.740867                      0.727900
# query17.txt                           0.818654                      0.883488
# query18.txt                           0.768675                      0.779163
# query19.txt                           0.900152                      0.864084
# query20.txt                           0.792214                      0.840504
#
#              16. Borussia Dortmund y el Signal Iduna Park.txt  \
# query1.txt                                           0.855062
# query2.txt                                           0.713668
# query3.txt                                           0.912246
# query4.txt                                           0.854924
# query5.txt                                           0.867179
# query6.txt                                           0.469446
# query7.txt                                           0.836823
# query8.txt                                           0.751748
# query9.txt                                           0.894757
# query10.txt                                          0.893224
# query11.txt                                          0.761420
# query12.txt                                          0.845678
# query13.txt                                          0.863016
# query14.txt                                          0.811677
# query15.txt                                          0.746538
# query16.txt                                          0.683340
# query17.txt                                          0.884556
# query18.txt                                          0.774747
# query19.txt                                          0.905981
# query20.txt                                          0.845547
#
#              20. Zoológico de Dortmund.txt  \
# query1.txt                         0.861528
# query2.txt                         0.758507
# query3.txt                         0.902393
# query4.txt                         0.870515
# query5.txt                         0.900464
# query6.txt                         0.560758
# query7.txt                         0.885015
# query8.txt                         0.779842
# query9.txt                         0.870583
# query10.txt                        0.865329
# query11.txt                        0.740849
# query12.txt                        0.893962
# query13.txt                        0.885225
# query14.txt                        0.829235
# query15.txt                        0.841408
# query16.txt                        0.826899
# query17.txt                        0.919177
# query18.txt                        0.844524
# query19.txt                        0.905654
# query20.txt                        0.868874
#
#              07. Real Madrid y el Estadio Santiago Bernabéu.txt  \
# query1.txt                                            0.853737
# query2.txt                                            0.731605
# query3.txt                                            0.871957
# query4.txt                                            0.871010
# query5.txt                                            0.889017
# query6.txt                                            0.438792
# query7.txt                                            0.864818
# query8.txt                                            0.742197
# query9.txt                                            0.838271
# query10.txt                                           0.866799
# query11.txt                                           0.787654
# query12.txt                                           0.872362
# query13.txt                                           0.863709
# query14.txt                                           0.806616
# query15.txt                                           0.773876
# query16.txt                                           0.726519
# query17.txt                                           0.884866
# query18.txt                                           0.804766
# query19.txt                                           0.921468
# query20.txt                                           0.848260
#
#              06. Gran Vía.txt  04. Parque del Retiro.txt  \
# query1.txt            0.885584                   0.880967
# query2.txt            0.767421                   0.774654
# query3.txt            0.921987                   0.883370
# query4.txt            0.891056                   0.904961
# query5.txt            0.897913                   0.843307
# query6.txt            0.517549                   0.505013
# query7.txt            0.865226                   0.903799
# query8.txt            0.788694                   0.762190
# query9.txt            0.892035                   0.854457
# query10.txt           0.907165                   0.864485
# query11.txt           0.772399                   0.759868
# query12.txt           0.878310                   0.851745
# query13.txt           0.891584                   0.869988
# query14.txt           0.824055                   0.753386
# query15.txt           0.793637                   0.816273
# query16.txt           0.752853                   0.780819
# query17.txt           0.910182                   0.881628
# query18.txt           0.837989                   0.847816
# query19.txt           0.923714                   0.934568
# query20.txt           0.866491                   0.850123
#
#              01. Historia de Madrid.txt  05. Gastronomía Madrileña.txt  \
# query1.txt                     0.886169                         0.879834
# query2.txt                     0.726766                         0.707880
# query3.txt                     0.926151                         0.882354
# query4.txt                     0.901735                         0.872872
# query5.txt                     0.881938                         0.951227
# query6.txt                     0.535211                         0.439917
# query7.txt                     0.858929                         0.873545
# query8.txt                     0.781026                         0.750776
# query9.txt                     0.889665                         0.804059
# query10.txt                    0.898461                         0.843504
# query11.txt                    0.738975                         0.702757
# query12.txt                    0.868577                         0.923039
# query13.txt                    0.886944                         0.877319
# query14.txt                    0.815553                         0.840759
# query15.txt                    0.814085                         0.812405
# query16.txt                    0.762170                         0.767058
# query17.txt                    0.908009                         0.945189
# query18.txt                    0.804153                         0.810423
# query19.txt                    0.919010                         0.916264
# query20.txt                    0.888596                         0.905554
#
#              03. Museo del Prado.txt  02. El Palacio Real.txt  \
# query1.txt                  0.800626                 0.905189
# query2.txt                  0.729187                 0.735409
# query3.txt                  0.762346                 0.874726
# query4.txt                  0.820857                 0.851384
# query5.txt                  0.726393                 0.900832
# query6.txt                  0.437842                 0.457961
# query7.txt                  0.844585                 0.869591
# query8.txt                  0.767129                 0.721899
# query9.txt                  0.827845                 0.809585
# query10.txt                 0.802076                 0.788856
# query11.txt                 0.729959                 0.669639
# query12.txt                 0.760734                 0.880406
# query13.txt                 0.791340                 0.838734
# query14.txt                 0.662152                 0.808316
# query15.txt                 0.752420                 0.830748
# query16.txt                 0.690126                 0.786564
# query17.txt                 0.765171                 0.923072
# query18.txt                 0.767565                 0.842428
# query19.txt                 0.893605                 0.900464
# query20.txt                 0.715877                 0.886726
#
#              19. Dortmund durante la Segunda Guerra Mundial.txt  \
# query1.txt                                            0.801199
# query2.txt                                            0.740646
# query3.txt                                            0.889198
# query4.txt                                            0.822166
# query5.txt                                            0.761178
# query6.txt                                            0.519984
# query7.txt                                            0.782980
# query8.txt                                            0.776699
# query9.txt                                            0.955214
# query10.txt                                           0.895768
# query11.txt                                           0.776941
# query12.txt                                           0.755378
# query13.txt                                           0.835816
# query14.txt                                           0.732945
# query15.txt                                           0.702592
# query16.txt                                           0.668435
# query17.txt                                           0.799822
# query18.txt                                           0.777271
# query19.txt                                           0.836588
# query20.txt                                           0.751443
#
#              18. La Reinoldikirche.txt  10. Madrid Río.txt  \
# query1.txt                    0.899141             0.896791
# query2.txt                    0.705165             0.731854
# query3.txt                    0.877915             0.890971
# query4.txt                    0.881861             0.890586
# query5.txt                    0.877472             0.922602
# query6.txt                    0.459711             0.441769
# query7.txt                    0.873729             0.890507
# query8.txt                    0.748896             0.751538
# query9.txt                    0.861085             0.848742
# query10.txt                   0.841959             0.863997
# query11.txt                   0.692201             0.719830
# query12.txt                   0.873214             0.916309
# query13.txt                   0.863688             0.887675
# query14.txt                   0.785495             0.821263
# query15.txt                   0.813237             0.823904
# query16.txt                   0.751474             0.774781
# query17.txt                   0.905409             0.934856
# query18.txt                   0.803681             0.830113
# query19.txt                   0.930803             0.935255
# query20.txt                   0.890636             0.905730
#
#              09. Nochevieja en Puerta del Sol.txt  08 Navidad en Madrid.txt
# query1.txt                               0.891824                  0.876821
# query2.txt                               0.683998                  0.711589
# query3.txt                               0.907130                  0.869108
# query4.txt                               0.872226                  0.870515
# query5.txt                               0.888277                  0.895489
# query6.txt                               0.514868                  0.519975
# query7.txt                               0.882321                  0.899765
# query8.txt                               0.745674                  0.766396
# query9.txt                               0.830860                  0.812544
# query10.txt                              0.839699                  0.818300
# query11.txt                              0.683258                  0.695949
# query12.txt                              0.888495                  0.913187
# query13.txt                              0.872393                  0.866256
# query14.txt                              0.813060                  0.829235
# query15.txt                              0.840204                  0.879438
# query16.txt                              0.791094                  0.843689
# query17.txt                              0.922168                  0.939866
# query18.txt                              0.782719                  0.821065
# query19.txt                              0.925582                  0.913201
# query20.txt                              0.916003                  0.906651

# %% [markdown]
# # Ranking, top 3 de los textos mas cercanos a las querys

# %% [markdown]
# 1. **Creación del diccionario de contenidos de consulta:**
#    - **Descripción:** Este bloque de código lee el contenido de cada archivo de consulta en el directorio especificado y lo almacena en un diccionario donde la clave es el nombre del archivo y el valor es el contenido del archivo en minúsculas.
#    - **Directorio de consultas:** Se especifica el directorio donde se encuentran los archivos de consulta en la variable `directory_queries`.
#    - **Lectura de archivos:** Se itera sobre cada archivo en el directorio de consultas y se lee su contenido utilizando un bucle `for` y la función `open`.
#    - **Almacenamiento en el diccionario:** El contenido de cada archivo se almacena en el diccionario `contenidos_consultas`, donde la clave es el nombre del archivo y el valor es su contenido.
#
# 2. **Obtención del ranking de documentos para cada consulta:**
#    - **Descripción:** Este bloque de código calcula los documentos más similares para cada consulta basándose en las similitudes coseno previamente calculadas y los contenidos de las consultas.
#    - **Iteración sobre las similitudes:** Se itera sobre cada fila del DataFrame `df_similitudes`, donde cada fila representa una consulta y cada columna representa un documento.
#    - **Ordenamiento de los documentos:** Para cada consulta, se ordenan los documentos por similitud coseno y se obtienen los índices de los tres documentos más similares.
#    - **Almacenamiento del ranking:** Los nombres de los documentos correspondientes a los tres índices más altos se almacenan en un diccionario `top_documentos_por_consulta`, donde la clave es el contenido de la consulta y el valor es una lista de los nombres de los documentos más similares.
#    - **Impresión del ranking:** Se imprime el ranking de documentos para cada consulta, mostrando la consulta y los documentos más similares.

# %%
# Directorio donde se encuentran los archivos de consulta
directory_queries = "/content/drive/MyDrive/querys"

# Diccionario para almacenar los contenidos de las consultas
contenidos_consultas = {}

# Leer el contenido de cada archivo de consulta y almacenarlo en el diccionario
for filename in os.listdir(directory_queries):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory_queries, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            text_query = file.read().lower()
            contenidos_consultas[filename] = text_query

# Crear un diccionario para almacenar los documentos más similares para cada consulta
top_documentos_por_consulta = {}

# Obtener el top 3 de documentos más similares para cada consulta
for index, row in df_similitudes.iterrows():
    # Ordenar los documentos por similitud coseno y obtener los índices de los tres más altos
    top_documentos_indices = row.argsort()[-3:][::-1]
    # Obtener los nombres de los documentos correspondientes a esos índices
    top_documentos = df_similitudes.columns[top_documentos_indices]
    # Almacenar los nombres de los documentos en el diccionario
    top_documentos_por_consulta[contenidos_consultas[index]] = top_documentos.tolist()

# Mostrar el ranking de documentos para cada consulta
for consulta, documentos in top_documentos_por_consulta.items():
    print(f"Consulta: {consulta}")
    print(f"Documentos más similares: {documentos}")
    print()
# Out:
# Consulta: historia medieval de las ciudades europeas
# Documentos más similares: ['02. El Palacio Real.txt', '18. La Reinoldikirche.txt', '10. Madrid Río.txt']
#
# Consulta: principales destinos turísticos en europa
# Documentos más similares: ['12. Westfalenpark.txt', '04. Parque del Retiro.txt', '06. Gran Vía.txt']
#
# Consulta: influencia de la realeza en la cultura europea
# Documentos más similares: ['11. Historia de Dortmund.txt', '01. Historia de Madrid.txt', '06. Gran Vía.txt']
#
# Consulta: importancia de los parques urbanos en las ciudades
# Documentos más similares: ['12. Westfalenpark.txt', '04. Parque del Retiro.txt', '01. Historia de Madrid.txt']
#
# Consulta: gastronomía típica en capitales europeas
# Documentos más similares: ['05. Gastronomía Madrileña.txt', '10. Madrid Río.txt', '02. El Palacio Real.txt']
#
# Consulta: eventos deportivos icónicos en europa
# Documentos más similares: ['14. Mercado de Navidad de Dortmund.txt', '13. Museo del Fútbol Alemán.txt', '20. Zoológico de Dortmund.txt']
#
# Consulta: celebraciones de navidad en ciudades europeas
# Documentos más similares: ['14. Mercado de Navidad de Dortmund.txt', '04. Parque del Retiro.txt', '08 Navidad en Madrid.txt']
#
# Consulta: museos de arte importantes en europa
# Documentos más similares: ['15. U-Tower - Centro de Arte y Creatividad.txt', '12. Westfalenpark.txt', '06. Gran Vía.txt']
#
# Consulta: efectos de la segunda guerra mundial en ciudades europeas
# Documentos más similares: ['19. Dortmund durante la Segunda Guerra Mundial.txt', '17. La cervecería Dortmund.txt', '11. Historia de Dortmund.txt']
#
# Consulta: arquitectura histórica en ciudades europeas
# Documentos más similares: ['06. Gran Vía.txt', '12. Westfalenpark.txt', '01. Historia de Madrid.txt']
#
# Consulta: clubes de fútbol famosos y sus estadios en europa
# Documentos más similares: ['12. Westfalenpark.txt', '07. Real Madrid y el Estadio Santiago Bernabéu.txt', '19. Dortmund durante la Segunda Guerra Mundial.txt']
#
# Consulta: transformación urbana y regeneración de espacios
# Documentos más similares: ['05. Gastronomía Madrileña.txt', '10. Madrid Río.txt', '08 Navidad en Madrid.txt']
#
# Consulta: tradición cervecera en ciudades europeas
# Documentos más similares: ['12. Westfalenpark.txt', '06. Gran Vía.txt', '10. Madrid Río.txt']
#
# Consulta: mercados y comercio tradicional en europa
# Documentos más similares: ['05. Gastronomía Madrileña.txt', '08 Navidad en Madrid.txt', '20. Zoológico de Dortmund.txt']
#
# Consulta: centros de arte y creatividad en ciudades modernas
# Documentos más similares: ['14. Mercado de Navidad de Dortmund.txt', '08 Navidad en Madrid.txt', '15. U-Tower - Centro de Arte y Creatividad.txt']
#
# Consulta: actividades de ocio y entretenimiento en ciudades metropolitanas
# Documentos más similares: ['14. Mercado de Navidad de Dortmund.txt', '08 Navidad en Madrid.txt', '20. Zoológico de Dortmund.txt']
#
# Consulta: conservación de la naturaleza y la vida silvestre en zonas urbanas
# Documentos más similares: ['05. Gastronomía Madrileña.txt', '08 Navidad en Madrid.txt', '10. Madrid Río.txt']
#
# Consulta: planificación de eventos culturales y festivales en ciudades
# Documentos más similares: ['12. Westfalenpark.txt', '14. Mercado de Navidad de Dortmund.txt', '04. Parque del Retiro.txt']
#
# Consulta: desarrollo del transporte y la infraestructura urbana
# Documentos más similares: ['10. Madrid Río.txt', '04. Parque del Retiro.txt', '18. La Reinoldikirche.txt']
#
# Consulta: impacto de la tecnología en la vida urbana
# Documentos más similares: ['09. Nochevieja en Puerta del Sol.txt', '08 Navidad en Madrid.txt', '10. Madrid Río.txt']
